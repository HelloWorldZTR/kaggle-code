# %%
import pandas as pd
import numpy as np

train_df = pd.read_csv("./data/train.csv")
test_df = pd.read_csv("./data/test.csv")

# %%
print("Percentage of missing data:")
for col in train_df.columns:
    print(col, train_df[col].isna().mean())

# Fill missing age data
age_avg = train_df["Age"].mean()
train_df["Age"] = train_df["Age"].fillna(age_avg)
# Out:
# Percentage of missing data:
# PassengerId 0.0
# Survived 0.0
# Pclass 0.0
# Name 0.0
# Sex 0.0
# Age 0.0
# SibSp 0.0
# Parch 0.0
# Ticket 0.0
# Fare 0.0
# Cabin 0.7710437710437711
# Embarked 0.002244668911335578
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
# Drop useless labels
wanted_cols = ["Survived", "Pclass", "Age", "Sex"]
train_df = train_df
print(train_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Drop useless labels
#       2 wanted_cols = ["Survived", "Pclass", "Age", "Sex"]
# ----> 3 train_df = train_df.columns[0, 1]
#       4 print(train_df)
#
# AttributeError: 'str' object has no attribute 'columns'
